# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import mpl_toolkits

# %%
from google.colab import drive
drive.mount('/content/kc_house_data.csv')

# %%
from google.colab import drive
drive.mount('/content/kc_house_data.csv')

# %%
file.describe()

# %%
file['bedrooms'].value_counts().plot(kind='bar')
plt.title('number of bedroom')
plt.xlabel('Bedrooms')
plt.ylabel('count')
sns.despine
# Out:
# <function seaborn.utils.despine>

# %%
plt.figure(figsize=(10,10))
sns.jointplot(x=file.lat.values,y=file.long.values,size=10)
plt.ylabel('Longitude',fontsize=12)
plt.xlabel('Latitude',fontsize=12)
plt.show()
sns.despine
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2182: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# <function seaborn.utils.despine>

# %%
plt.scatter(file.price,file.sqft_living)
plt.title("Price vs Square Feet")
# Out:
# Text(0.5, 1.0, 'Price vs Square Feet')

# %%
plt.scatter(file.price,file.long)
plt.title("Price vs Location Of Area")
# Out:
# Text(0.5, 1.0, 'Price vs Location Of Area')

# %%
plt.scatter(file.bedrooms,file.price)
plt.title("Bedrooms And Price")
plt.xlabel("Bedrooms")
plt.ylabel("Price")
plt.show()
sns.despine
# Out:
# <function seaborn.utils.despine>

# %%
plt.scatter((file['sqft_living']+file['sqft_basement']),file['price'])

# %%
plt.scatter(file.waterfront,file.price)
plt.title("Waterfront vs Price(0= no waterfront)")
# Out:
# Text(0.5, 1.0, 'Waterfront vs Price(0= no waterfront)')

# %%
plt.scatter(file.floors,file.price)

# %%
plt.scatter(file.condition,file.price)

# %%
plt.scatter(file.zipcode,file.price)
plt.title("Which is the pricey location by zipcode?")
# Out:
# Text(0.5, 1.0, 'Which is the pricey location by zipcode?')
